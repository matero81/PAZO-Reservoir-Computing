# %% [markdown]
# This cell is used only if the included functions are changed while running the jupyter code

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Include libraries

# %%
# Python 3.11.0
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# Enable interactive plots in Jupyter Notebook (requires the ipympl package)
# %matplotlib widget

# Import essential libraries for data manipulation, visualization, and computation
import matplotlib.pyplot as plt  # For plotting
from matplotlib.animation import FuncAnimation
import os  # For directory and file management
import pandas as pd  # For handling dataframes and CSV files
import numpy as np  # For numerical computations
import random  # For generating random numbers
from PIL import Image  # For image processing
from IPython.display import clear_output  # For clearing cell outputs

# Import libraries for machine learning and neural networks
from sklearn.manifold import TSNE  # For dimensionality reduction (t-SNE)

# Import the MNIST dataset from TensorFlow (only if you're online or the file has been already imported before)
from tensorflow.keras.datasets import mnist

# Import custom utility functions from the general functions module
from functions_general import *

# %%
plt.close('all')

# %% [markdown]
# ## Dataset Parameters

# %%
num_digits_train = 60000 # Number of images for training
num_digits_test = 10000 # Number of images for testing
start_train = 0 # Index of first image in training
start_test = 0 # Index of first image in testing

################## Put the number of bits here
num_bits = 4

digit_rows_no_chop = 28 
digit_cols_no_chop = 28

digit_cols = num_bits
digit_rows = digit_cols_no_chop//digit_cols*digit_rows_no_chop #196
print(f'Digit rows: {digit_rows}')
# Out:
# Digit rows: 196

# %% [markdown]
# ## Dataset Load, binarization, chopping and merging

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data() # Load the MNIST data. For the first time, the data will be downloaded, if the file was already been downloaded, it will be stored at the cache folder

# Use the following command when you are offline and the mnist dataset hasn't been installed previously:
#(x_train, y_train), (x_test, y_test) = import_mnist_offline('.\MNIST_data\mnist.npz')

digit_train_no_binarized = [np.zeros(shape=(digit_rows_no_chop, digit_cols_no_chop)) for i in range(0, num_digits_train)]
digit_test_no_binarized = [np.zeros(shape=(digit_rows_no_chop, digit_cols_no_chop)) for i in range(0, num_digits_test)]

digit_train_no_chop = [np.zeros(shape=(digit_rows_no_chop, digit_cols_no_chop)) for i in range(0, num_digits_train)]
digit_test_no_chop = [np.zeros(shape=(digit_rows_no_chop, digit_cols_no_chop)) for i in range(0, num_digits_test)]

digit_train = [[np.zeros(shape=(digit_rows, digit_cols))] for i in range(0, num_digits_train)]
digit_test = [[np.zeros(shape=(digit_rows, digit_cols))] for i in range(0, num_digits_test)]


digit_train_class = y_train[0+start_train:num_digits_train+start_train]
for i in range(0, num_digits_train):
    digit_train_no_binarized[i] = x_train[i+start_train]
    digit_train_no_chop[i] = np.round(digit_train_no_binarized[i]/256)
    digit_train[i] = np.reshape(digit_train[i], (digit_rows,digit_cols))
    for j in range(digit_cols_no_chop//digit_cols):
        digit_train[i][digit_rows_no_chop*j:digit_rows_no_chop*(j+1), :] = digit_train_no_chop[i][:, digit_cols*j:digit_cols*(j+1)]
    
digit_test_class = y_test[0+start_test:num_digits_test+start_test]
for i in range(0, num_digits_test):
    digit_test_no_binarized[i] = x_test[i+start_test]
    digit_test_no_chop[i] = np.round(digit_test_no_binarized[i]/256)
    digit_test[i] = np.reshape(digit_test[i], (digit_rows,digit_cols))
    for j in range(digit_cols_no_chop//digit_cols):
        digit_test[i][digit_rows_no_chop*j:digit_rows_no_chop*(j+1), :] = digit_test_no_chop[i][:, digit_cols*j:digit_cols*(j+1)]

# %% [markdown]
# ## Digit display: 8 bit, binarized, chopped and merged

# %%
out_dir_digit_figs = './out_data/Figs_digits/'
if not os.path.exists(out_dir_digit_figs):
  os.makedirs(out_dir_digit_figs)

def plot_and_save_digit(digit_data, digit_class, idx, title_prefix, filename_prefix):
  if title_prefix == 'Cropped and Merged Digit':
    plt.figure(figsize=(4, 8))
    plt.imshow(digit_data, aspect=0.1, cmap='gray')
  else:
    plt.figure()
    plt.imshow(digit_data, cmap='gray')
  plt.title(f'{title_prefix}: {digit_class}')
  plt.savefig(out_dir_digit_figs + f'{filename_prefix}_{digit_class}_idx_{idx}.png')
  np.savetxt(out_dir_digit_figs + f'{filename_prefix}_{digit_class}_idx_{idx}.txt', digit_data)

indices_to_plot = [24934, 0, 30000]

for idx_to_plot in indices_to_plot:
  plot_and_save_digit(digit_train_no_binarized[idx_to_plot], digit_train_class[idx_to_plot], idx_to_plot, 'Digit 8bit', 'digit_8bit')
  plot_and_save_digit(digit_train_no_chop[idx_to_plot], digit_train_class[idx_to_plot], idx_to_plot, 'Binarized Digit', 'binarized_digit')
  plot_and_save_digit(digit_train[idx_to_plot], digit_train_class[idx_to_plot], idx_to_plot, 'Cropped and Merged Digit', 'cropped_and_merged_digit')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Many digits plot

# %%
nx_images = 9
ny_images = 3
total_images = nx_images * ny_images
idx_first_image = 150
images_vector = [digit_train_no_binarized[idx_it] for idx_it in range(idx_first_image, idx_first_image+total_images)]

# Define the size of the separation space (in pixels)
separation = 2

# Create a grid of 9x3 images with separation spaces
grid_width = nx_images * 28 + (nx_images-1) * separation
grid_height = ny_images * 28 + (ny_images-1) * separation
grid = 255*np.ones((grid_height, grid_width))  # Initialize with ones for white background

for i in range(ny_images):
    for j in range(nx_images):
        start_row = i * (28 + separation)
        start_col = j * (28 + separation)
        grid[start_row:start_row + 28, start_col:start_col + 28] = images_vector[i * nx_images + j]

# Display the grid of images
plt.figure()
plt.imshow(grid, cmap='gray')
plt.axis('off')  # Hide the axes

plt.show()

# Save the grid of images:
grid_image = Image.fromarray((grid).astype(np.uint8)) # Save the image as a BMP file 
grid_image.save(out_dir_digit_figs + 'digits_grid_image.bmp')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Open files for experimental data of bit impulses

# %%
dataset = '12122024_20-14-55'

relative_path = f'Data to process/{num_bits} bits/{dataset}/'
folders = os.listdir(relative_path)

parameters_data = pd.read_csv(f'{relative_path}/Parameters.txt', sep='\t', header=0)
start_waiting_time = parameters_data['Time before sequence E6 (ms)'].to_numpy()
T_on = parameters_data['T_on E6 (ms)'].to_numpy()
T_off = parameters_data['T_off E6 (ms)'].to_numpy()

all_data = []
for folder in folders:
    single_folder_path = f'{relative_path}{folder}'
    if os.path.isdir(single_folder_path):
        files_in_folder = os.listdir(single_folder_path)
        set_data = {}
        for single_file_name in files_in_folder:
            single_data = np.loadtxt(
                f'{single_folder_path}/{single_file_name}',
                  delimiter='\t')
            single_data_dict = {}
            single_data_dict['time'] = single_data[:, 1]
            single_data_dict['intensity'] = single_data[:, 2]
            set_data[single_file_name.replace('.txt', '')] = single_data_dict
        all_data.append(set_data)

# %% [markdown]
# ## Plot the experimental data and select the data at 100ms after the last bit

# %%
out_dir_plot_figures = './out_data/Single_data_plots/'
if not os.path.exists(out_dir_plot_figures):
    os.makedirs(out_dir_plot_figures)
plt.close('all')
time_offset = 100
data_at_specific_time = {}
for key in all_data[0].keys():
    data_at_specific_time[key] = []
for set_idx, single_set in enumerate(all_data):
    plt.figure()
    idx_max = np.argmax(single_set['1'*num_bits]['intensity'])
    for bin_number, single_data in single_set.items():
        time_v = single_data['time']
        intensity_v = single_data['intensity']
        idx_beggining = find_nearest_value_index(time_v, start_waiting_time)
        idx_at_specific_time = find_nearest_value_index(time_v, time_v[idx_max] + T_off + time_offset)
        data_at_specific_time[bin_number].append(intensity_v[idx_at_specific_time].item())
        plt.plot(time_v[idx_beggining:], intensity_v[idx_beggining:], label=bin_number)
        plt.plot(time_v[idx_at_specific_time], intensity_v[idx_at_specific_time], 'ro')
    plt.xlabel('Time, ms')
    plt.ylabel('Intensity, A.U.')
    plt.title(f'Intensity vs Time Set {set_idx}')
    plt.subplots_adjust(right=0.8)
    plt.legend(bbox_to_anchor=(1, 1))
    plt.show()
    plt.savefig(out_dir_plot_figures+f'Set_{set_idx}_dataset_{dataset}_plot.png', format="png", dpi=1200)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot the Boxplot

# %%
out_dir_boxplot = './out_data/Boxplot/'
if not os.path.exists(out_dir_boxplot):
    os.makedirs(out_dir_boxplot)
df_PAZO = pd.DataFrame(data_at_specific_time)
df_PAZO.to_csv(out_dir_boxplot+f'Dataframe_for_boxplot_{dataset}.csv')

# Box plot:
binary_numbers = df_PAZO.columns.values.tolist()
x_vector = [*range(1, len(binary_numbers)+1)]
plt.figure()
plt.subplots_adjust(bottom=0.2)
plt.boxplot(df_PAZO)
plt.xticks(x_vector, binary_numbers, rotation='vertical')
plt.title(f'Boxplot at T after: {time_offset}ms from last pulse')
plt.xlabel("Binary number")
plt.ylabel("Intensity, A.U.")
plt.show()
plt.savefig(out_dir_boxplot+f'Boxplot_{dataset}.png', format="png", dpi=1200)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## TSNE 2D calculation

# %%
out_dir_TSNE = './out_data/TNSE/'
if not os.path.exists(out_dir_TSNE):
    os.makedirs(out_dir_TSNE)
selector_reservoir = 0
n_tsne = 10000
random.seed(5)
(digit_train_reduced_np, digit_test_reduced_np) = assign_experimental_data_with_digit(data_at_specific_time, digit_rows, num_digits_train, num_digits_test, digit_train, digit_test, selector_reservoir)

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(digit_train_reduced_np[:n_tsne,:])
plt.figure(figsize=(10, 8)) 
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=digit_train_class[:n_tsne].astype(int), cmap='tab10', alpha=0.7) 
plt.colorbar(scatter, ticks=range(10)) 
plt.title('t-SNE of MNIST Handwritten Digits') 
plt.xlabel('t-SNE Component 1') 
plt.ylabel('t-SNE Component 2') 
plt.show()
plt.savefig(out_dir_TSNE+f'TSNE_2D_n_{n_tsne}.png', format="png", dpi=1200)

matrix_tnse = np.vstack((X_tsne[:, 0], X_tsne[:, 1], digit_train_class[:n_tsne]))
np.savetxt(out_dir_TSNE+'matrix_tnse_2D.txt', matrix_tnse.T)
# Out:
# Training set: 100%|██████████| 60000/60000 [00:23<00:00, 2542.32it/s]
# Testing set: 100%|██████████| 10000/10000 [00:03<00:00, 2525.94it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## TSNE 3D calculation

# %%
out_dir_TSNE = './out_data/TNSE/'
if not os.path.exists(out_dir_TSNE):
    os.makedirs(out_dir_TSNE)
selector_reservoir = 1 #Instead of PAZO information, the vector is filled with the last bit of the image
n_tsne = 1000
random.seed(5)
(digit_train_reduced_np, digit_test_reduced_np) = assign_experimental_data_with_digit(data_at_specific_time, digit_rows, num_digits_train, num_digits_test, digit_train, digit_test, selector_reservoir)

tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(digit_train_reduced_np[:n_tsne,:])
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], c=digit_train_class[:n_tsne].astype(int), cmap='tab10', alpha=0.7) 
legend = ax.legend(*scatter.legend_elements(), title="Digits")
ax.add_artist(legend)
ax.set_title('t-SNE of MNIST Handwritten Digits') 
ax.set_xlabel('t-SNE Component 1') 
ax.set_ylabel('t-SNE Component 2') 
ax.set_zlabel('t-SNE Component 3') 
plt.show()
plt.savefig(out_dir_TSNE+f'TSNE_3D_n_{n_tsne}.png', format="png", dpi=1200)

matrix_tnse = np.vstack((X_tsne[:, 0], X_tsne[:, 1], digit_train_class[:n_tsne]))
np.savetxt(out_dir_TSNE+'matrix_tnse_3D.txt', matrix_tnse.T)
# Out:
# Training set: 100%|██████████| 60000/60000 [00:20<00:00, 2882.49it/s]
# Testing set: 100%|██████████| 10000/10000 [00:03<00:00, 2938.61it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Export TSNE 3D gif

# %%
# 1. Setup the figure
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 2. Initial plot (Plot once, then update view)
# This is much faster than ax.clear() every time
scatter = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], 
                     c=digit_train_class[:n_tsne].astype(int), 
                     cmap='tab10', alpha=0.7) 

ax.set_title('t-SNE of MNIST Handwritten Digits') 
ax.set_xlabel('t-SNE Component 1') 
ax.set_ylabel('t-SNE Component 2') 
ax.set_zlabel('t-SNE Component 3')

# 3. Update function: ONLY changes the camera angle
def update(angle):
    ax.view_init(elev=30, azim=angle)
    return scatter,

# 4. Create the animation object
# frames=range(0, 360, 5) creates the rotation sequence
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 5), interval=100)

# 5. Save the animation
# Note: This requires the 'pillow' library installed (pip install pillow)
output_path = out_dir_TSNE + 'tsne_animation_3d.gif'
print(f"Saving animation to {output_path}...")

ani.save(output_path, writer='pillow', fps=10)

plt.close(fig)
print("Done!")
# Out:
# Saving animation to ./out_data/TNSE/tsne_animation_3d.gif...
# Done!

# %% [markdown]
# ## Loop to evaluate the accuracy in n repetitions:

# %%
out_dir_training_outputs = './out_data/Training_outputs/'
if not os.path.exists(out_dir_training_outputs):
    os.makedirs(out_dir_training_outputs)
plot_data = 1
save_data = 1
verbose_training = 1
clear_output_in_iteration = 0
save_first_digit = 1 # Save information about the first digit
data_first_digit_train_v = []
data_first_digit_test_v = []

selector_reservoir = 0

epochs = 800
batch_size = 1500

n_repetitions = 1
accuracy_v = [] # Accuracy vector to store the values of accuracy for the different repetitions
random.seed(5)
for repetition in range(n_repetitions):
    print(f'Doing calculations for repetition {repetition}')
    ##################################################
    # Convert PAZO data into the MNIST data:
    print('Assigning experimental data with digits')
    (digit_train_reduced_np, digit_test_reduced_np) = assign_experimental_data_with_digit(data_at_specific_time, digit_rows, num_digits_train, num_digits_test, digit_train, digit_test, selector_reservoir)
    data_first_digit_train_v.append(digit_train_reduced_np[0][:])
    data_first_digit_test_v.append(digit_test_reduced_np[0][:])
        
    ##################################################
    # Perform the training
    print('Performing training')
    (history, conf_matrix, conf_matrix_norm, test_accuracy, y_pred_class, test_out) = perform_training(start_train, start_test, num_digits_train, num_digits_test, digit_train_class, digit_test_class, epochs, batch_size, digit_train_reduced_np, digit_test_reduced_np, verbose_training)
    
    if plot_data == 1:
        plot_training_data(out_dir_training_outputs, history, conf_matrix, conf_matrix_norm, repetition)
    
    np.savetxt(out_dir_training_outputs+f'conf_matrix_ep{epochs}'+'_batch'+str(batch_size)+'.txt', conf_matrix)
    np.savetxt(out_dir_training_outputs+'conf_matrix_norm_ep'+str(epochs)+'_batch'+str(batch_size)+'.txt', conf_matrix_norm)
    print(f'Test accuracy: {test_accuracy}')
    accuracy_v.append(test_accuracy)
    if clear_output_in_iteration == 1:
        plt.close('all')
        clear_output(wait=True)

# Box plot:
plt.figure()
plt.boxplot(accuracy_v)
plt.title(f'Boxplot for {n_repetitions} repetitions')
plt.ylabel("Accuracy")
plt.show()

out_dir_accuracy = f'./out_data/Accuracy/{num_bits} bits/{dataset}/'

if save_data == 1:
    if not os.path.exists(out_dir_accuracy):
        os.makedirs(out_dir_accuracy)
    np.savetxt(out_dir_accuracy + f'accuracy_vector_{n_repetitions}_repetitions_{dataset}.txt', accuracy_v)
    

if save_first_digit == 1:
    if not os.path.exists(out_dir_accuracy):
        os.makedirs(out_dir_accuracy)
    np.savetxt(out_dir_accuracy + f'first_digit_train_{dataset}.txt', np.array(data_first_digit_train_v).T)
    np.savetxt(out_dir_accuracy + f'first_digit_test_{dataset}.txt', np.array(data_first_digit_test_v).T)

# Save the confusion matrix data:
confusion_data_matrix = np.column_stack([test_out[:,0], y_pred_class])
df_confusion_data_matrix = pd.DataFrame(confusion_data_matrix, columns=['Test out', 'Predicted'])
df_confusion_data_matrix.to_csv(out_dir_accuracy+f'confusion_data_matrix_{dataset}.csv', index=False)
# Out:
# Doing calculations for repetition 0
# Assigning experimental data with digits
# Training set: 100%|██████████| 60000/60000 [00:26<00:00, 2256.87it/s]
# Testing set: 100%|██████████| 10000/10000 [00:03<00:00, 2518.93it/s]
# Performing training
# Epoch 1/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2522 - loss: 2.3118
# Epoch 2/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6062 - loss: 1.2764
# Epoch 3/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7444 - loss: 0.8835
# Epoch 4/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8018 - loss: 0.7063
# Epoch 5/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8314 - loss: 0.6091
# Epoch 6/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.5484
# Epoch 7/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8600 - loss: 0.5068
# Epoch 8/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.4766
# Epoch 9/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8724 - loss: 0.4535
# Epoch 10/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8763 - loss: 0.4355
# Epoch 11/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8799 - loss: 0.4208
# Epoch 12/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8827 - loss: 0.4086
# Epoch 13/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8851 - loss: 0.3985
# Epoch 14/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8878 - loss: 0.3898
# Epoch 15/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8898 - loss: 0.3822
# Epoch 16/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8909 - loss: 0.3757
# Epoch 17/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8925 - loss: 0.3698
# Epoch 18/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8939 - loss: 0.3647
# Epoch 19/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.3602
# Epoch 20/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8957 - loss: 0.3560
# Epoch 21/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8967 - loss: 0.3523
# Epoch 22/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.3489
# Epoch 23/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.3459
# Epoch 24/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8995 - loss: 0.3431
# Epoch 25/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9002 - loss: 0.3405
# Epoch 26/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9014 - loss: 0.3381
# Epoch 27/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9020 - loss: 0.3359
# Epoch 28/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9025 - loss: 0.3338
# Epoch 29/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9030 - loss: 0.3320
# Epoch 30/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9036 - loss: 0.3301
# Epoch 31/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9037 - loss: 0.3285
# Epoch 32/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9041 - loss: 0.3270
# Epoch 33/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9046 - loss: 0.3256
# Epoch 34/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9051 - loss: 0.3242
# Epoch 35/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9052 - loss: 0.3229
# Epoch 36/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.3217
# Epoch 37/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9060 - loss: 0.3206
# Epoch 38/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9064 - loss: 0.3195
# Epoch 39/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9067 - loss: 0.3185
# Epoch 40/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.3176
# Epoch 41/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9075 - loss: 0.3167
# Epoch 42/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9075 - loss: 0.3158
# Epoch 43/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9078 - loss: 0.3151
# Epoch 44/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9075 - loss: 0.3142
# Epoch 45/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9079 - loss: 0.3135
# Epoch 46/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9083 - loss: 0.3128
# Epoch 47/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.3121
# Epoch 48/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9085 - loss: 0.3115
# Epoch 49/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9086 - loss: 0.3109
# Epoch 50/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9086 - loss: 0.3103
# Epoch 51/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9091 - loss: 0.3097
# Epoch 52/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9090 - loss: 0.3092
# Epoch 53/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9097 - loss: 0.3087
# Epoch 54/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9094 - loss: 0.3082
# Epoch 55/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.3078
# Epoch 56/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9098 - loss: 0.3073
# Epoch 57/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9099 - loss: 0.3068
# Epoch 58/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9102 - loss: 0.3065
# Epoch 59/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9102 - loss: 0.3060
# Epoch 60/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9100 - loss: 0.3056
# Epoch 61/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.3053
# Epoch 62/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9107 - loss: 0.3050
# Epoch 63/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.3046
# Epoch 64/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9104 - loss: 0.3043
# Epoch 65/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.3040
# Epoch 66/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9111 - loss: 0.3037
# Epoch 67/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9112 - loss: 0.3034
# Epoch 68/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9112 - loss: 0.3031
# Epoch 69/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9115 - loss: 0.3028
# Epoch 70/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9115 - loss: 0.3026
# Epoch 71/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9110 - loss: 0.3024
# Epoch 72/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9114 - loss: 0.3021
# Epoch 73/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9114 - loss: 0.3018
# Epoch 74/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9114 - loss: 0.3016
# Epoch 75/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9117 - loss: 0.3014
# Epoch 76/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9117 - loss: 0.3010
# Epoch 77/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9117 - loss: 0.3009
# Epoch 78/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9117 - loss: 0.3007
# Epoch 79/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.3005
# Epoch 80/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9116 - loss: 0.3003
# Epoch 81/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9118 - loss: 0.3002
# Epoch 82/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9123 - loss: 0.3000
# Epoch 83/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.2998
# Epoch 84/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9124 - loss: 0.2996
# Epoch 85/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2995
# Epoch 86/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9122 - loss: 0.2993
# Epoch 87/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.2991
# Epoch 88/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.2990
# Epoch 89/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2989
# Epoch 90/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9122 - loss: 0.2986
# Epoch 91/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.2985
# Epoch 92/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9122 - loss: 0.2984
# Epoch 93/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.2983
# Epoch 94/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9122 - loss: 0.2981
# Epoch 95/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9125 - loss: 0.2979
# Epoch 96/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9125 - loss: 0.2978
# Epoch 97/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9122 - loss: 0.2978
# Epoch 98/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9128 - loss: 0.2977
# Epoch 99/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9123 - loss: 0.2976
# Epoch 100/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2974
# Epoch 101/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.2973
# Epoch 102/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9128 - loss: 0.2972
# Epoch 103/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2971
# Epoch 104/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9128 - loss: 0.2971
# Epoch 105/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.2970
# Epoch 106/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9128 - loss: 0.2969
# Epoch 107/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2968
# Epoch 108/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.2966
# Epoch 109/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2966
# Epoch 110/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2964
# Epoch 111/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2964
# Epoch 112/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9131 - loss: 0.2963
# Epoch 113/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.2962
# Epoch 114/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2962
# Epoch 115/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.2960
# Epoch 116/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2959
# Epoch 117/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2960
# Epoch 118/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2959
# Epoch 119/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9131 - loss: 0.2957
# Epoch 120/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.2956
# Epoch 121/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2956
# Epoch 122/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2955
# Epoch 123/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2955
# Epoch 124/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.2955
# Epoch 125/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2953
# Epoch 126/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2954
# Epoch 127/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2952
# Epoch 128/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.2952
# Epoch 129/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2951
# Epoch 130/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2950
# Epoch 131/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2950
# Epoch 132/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2949
# Epoch 133/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9133 - loss: 0.2949
# Epoch 134/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.2948
# Epoch 135/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2948
# Epoch 136/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2948
# Epoch 137/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2947
# Epoch 138/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2946
# Epoch 139/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2945
# Epoch 140/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2946
# Epoch 141/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.2945
# Epoch 142/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2944
# Epoch 143/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2943
# Epoch 144/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9132 - loss: 0.2944
# Epoch 145/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2943
# Epoch 146/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.2944
# Epoch 147/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2943
# Epoch 148/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2942
# Epoch 149/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2941
# Epoch 150/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2941
# Epoch 151/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2941
# Epoch 152/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2940
# Epoch 153/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2940
# Epoch 154/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2941
# Epoch 155/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2940
# Epoch 156/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2939
# Epoch 157/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2939
# Epoch 158/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2939
# Epoch 159/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2938
# Epoch 160/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2938
# Epoch 161/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2938
# Epoch 162/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2937
# Epoch 163/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2937
# Epoch 164/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.2936
# Epoch 165/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2936
# Epoch 166/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2936
# Epoch 167/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2935
# Epoch 168/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2936
# Epoch 169/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2934
# Epoch 170/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2935
# Epoch 171/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2935
# Epoch 172/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2934
# Epoch 173/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2934
# Epoch 174/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2934
# Epoch 175/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2933
# Epoch 176/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.2932
# Epoch 177/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2932
# Epoch 178/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2933
# Epoch 179/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2932
# Epoch 180/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2933
# Epoch 181/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2931
# Epoch 182/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2931
# Epoch 183/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2932
# Epoch 184/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2932
# Epoch 185/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2932
# Epoch 186/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2931
# Epoch 187/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2931
# Epoch 188/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2930
# Epoch 189/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2930
# Epoch 190/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2930
# Epoch 191/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2929
# Epoch 192/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2929
# Epoch 193/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2929
# Epoch 194/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2929
# Epoch 195/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2929
# Epoch 196/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2929
# Epoch 197/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2928
# Epoch 198/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2928
# Epoch 199/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2928
# Epoch 200/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2928
# Epoch 201/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2929
# Epoch 202/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2928
# Epoch 203/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2928
# Epoch 204/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2927
# Epoch 205/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2926
# Epoch 206/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2926
# Epoch 207/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2928
# Epoch 208/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2926
# Epoch 209/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2926
# Epoch 210/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2926
# Epoch 211/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2927
# Epoch 212/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2926
# Epoch 213/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2925
# Epoch 214/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2925
# Epoch 215/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2926
# Epoch 216/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2925
# Epoch 217/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2925
# Epoch 218/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2925
# Epoch 219/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2925
# Epoch 220/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2926
# Epoch 221/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2924
# Epoch 222/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2924
# Epoch 223/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2924
# Epoch 224/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2925
# Epoch 225/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2926
# Epoch 226/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2924
# Epoch 227/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2924
# Epoch 228/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2923
# Epoch 229/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2924
# Epoch 230/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2924
# Epoch 231/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2924
# Epoch 232/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2924
# Epoch 233/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2923
# Epoch 234/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2923
# Epoch 235/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2923
# Epoch 236/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2923
# Epoch 237/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2922
# Epoch 238/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2923
# Epoch 239/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2923
# Epoch 240/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2924
# Epoch 241/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2923
# Epoch 242/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2923
# Epoch 243/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2922
# Epoch 244/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2922
# Epoch 245/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2922
# Epoch 246/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2922
# Epoch 247/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2923
# Epoch 248/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2922
# Epoch 249/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2922
# Epoch 250/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2922
# Epoch 251/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2921
# Epoch 252/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2922
# Epoch 253/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2921
# Epoch 254/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2921
# Epoch 255/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2922
# Epoch 256/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2922
# Epoch 257/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2922
# Epoch 258/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2920
# Epoch 259/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2921
# Epoch 260/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2921
# Epoch 261/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2921
# Epoch 262/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2920
# Epoch 263/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2920
# Epoch 264/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2920
# Epoch 265/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2919
# Epoch 266/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2919
# Epoch 267/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2920
# Epoch 268/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2920
# Epoch 269/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2920
# Epoch 270/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2921
# Epoch 271/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2920
# Epoch 272/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2919
# Epoch 273/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2920
# Epoch 274/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2919
# Epoch 275/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2920
# Epoch 276/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2919
# Epoch 277/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2918
# Epoch 278/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2919
# Epoch 279/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2919
# Epoch 280/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2919
# Epoch 281/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2919
# Epoch 282/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2919
# Epoch 283/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2919
# Epoch 284/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2919
# Epoch 285/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2918
# Epoch 286/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2919
# Epoch 287/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2919
# Epoch 288/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2919
# Epoch 289/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2919
# Epoch 290/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2918
# Epoch 291/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2918
# Epoch 292/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2918
# Epoch 293/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2918
# Epoch 294/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 295/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2917
# Epoch 296/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2918
# Epoch 297/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2918
# Epoch 298/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2918
# Epoch 299/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2919
# Epoch 300/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 301/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2918
# Epoch 302/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2918
# Epoch 303/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2918
# Epoch 304/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2918
# Epoch 305/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2917
# Epoch 306/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2918
# Epoch 307/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2918
# Epoch 308/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2918
# Epoch 309/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 310/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2917
# Epoch 311/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 312/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 313/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2919
# Epoch 314/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 315/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2917
# Epoch 316/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2918
# Epoch 317/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2916
# Epoch 318/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2917
# Epoch 319/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2917
# Epoch 320/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2917
# Epoch 321/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2916
# Epoch 322/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 323/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2917
# Epoch 324/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 325/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 326/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 327/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2917
# Epoch 328/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 329/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2917
# Epoch 330/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2916
# Epoch 331/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 332/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2917
# Epoch 333/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 334/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 335/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 336/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2916
# Epoch 337/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2916
# Epoch 338/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2917
# Epoch 339/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2916
# Epoch 340/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2917
# Epoch 341/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2916
# Epoch 342/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2917
# Epoch 343/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2916
# Epoch 344/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 345/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2916
# Epoch 346/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2916
# Epoch 347/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 348/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2916
# Epoch 349/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 350/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2915
# Epoch 351/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2916
# Epoch 352/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2916
# Epoch 353/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 354/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2916
# Epoch 355/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2916
# Epoch 356/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2915
# Epoch 357/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 358/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2916
# Epoch 359/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2915
# Epoch 360/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2915
# Epoch 361/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 362/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 363/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 364/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2915
# Epoch 365/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 366/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2915
# Epoch 367/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2915
# Epoch 368/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2915
# Epoch 369/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 370/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 371/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2915
# Epoch 372/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2916
# Epoch 373/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 374/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2915
# Epoch 375/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 376/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2915
# Epoch 377/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 378/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2915
# Epoch 379/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2916
# Epoch 380/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.2914
# Epoch 381/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2915
# Epoch 382/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 383/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 384/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 385/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 386/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 387/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2914
# Epoch 388/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2914
# Epoch 389/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 390/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 391/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 392/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 393/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2915
# Epoch 394/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2915
# Epoch 395/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 396/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 397/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 398/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 399/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 400/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2915
# Epoch 401/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2914
# Epoch 402/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2915
# Epoch 403/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2914
# Epoch 404/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 405/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 406/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 407/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 408/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2914
# Epoch 409/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 410/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.2915
# Epoch 411/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 412/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 413/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 414/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 415/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 416/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 417/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 418/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2915
# Epoch 419/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2915
# Epoch 420/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 421/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 422/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 423/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 424/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 425/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 426/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 427/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2914
# Epoch 428/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 429/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 430/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2914
# Epoch 431/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 432/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 433/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 434/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 435/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 436/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2913
# Epoch 437/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 438/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 439/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 440/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2914
# Epoch 441/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 442/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 443/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 444/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 445/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 446/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 447/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2914
# Epoch 448/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 449/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 450/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 451/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 452/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2912
# Epoch 453/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 454/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 455/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 456/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 457/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 458/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 459/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 460/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 461/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 462/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 463/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 464/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 465/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 466/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 467/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 468/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 469/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 470/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2914
# Epoch 471/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 472/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2913
# Epoch 473/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 474/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 475/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 476/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 477/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2914
# Epoch 478/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2913
# Epoch 479/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 480/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 481/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 482/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 483/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 484/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 485/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2912
# Epoch 486/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 487/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 488/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 489/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9137 - loss: 0.2913
# Epoch 490/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 491/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 492/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 493/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2912
# Epoch 494/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 495/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 496/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 497/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 498/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 499/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 500/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 501/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9146 - loss: 0.2912
# Epoch 502/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 503/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 504/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 505/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 506/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2913
# Epoch 507/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 508/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 509/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 510/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 511/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 512/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2913
# Epoch 513/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2912
# Epoch 514/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2913
# Epoch 515/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 516/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 517/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 518/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 519/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 520/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 521/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 522/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 523/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 524/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 525/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 526/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2912
# Epoch 527/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 528/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 529/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 530/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 531/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 532/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 533/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 534/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2913
# Epoch 535/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 536/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 537/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 538/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2912
# Epoch 539/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 540/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 541/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2913
# Epoch 542/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2913
# Epoch 543/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 544/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 545/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 546/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 547/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 548/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2913
# Epoch 549/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 550/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 551/800
# ...
# Epoch 623/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 624/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 625/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 626/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 627/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 628/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 629/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2910
# Epoch 630/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 631/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 632/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 633/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.2912
# Epoch 634/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 635/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 636/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 637/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 638/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2912
# Epoch 639/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2911
# Epoch 640/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2912
# Epoch 641/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 642/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 643/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 644/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2911
# Epoch 645/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 646/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2911
# Epoch 647/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2912
# Epoch 648/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 649/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2912
# Epoch 650/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 651/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 652/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 653/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2911
# Epoch 654/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 655/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 656/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 657/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 658/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 659/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 660/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2910
# Epoch 661/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 662/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 663/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 664/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 665/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 666/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 667/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 668/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 669/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 670/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 671/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2910
# Epoch 672/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 673/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 674/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 675/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 676/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 677/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 678/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 679/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 680/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9147 - loss: 0.2911
# Epoch 681/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2911
# Epoch 682/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 683/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 684/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 685/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 686/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 687/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 688/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 689/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 690/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 691/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2912
# Epoch 692/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 693/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9146 - loss: 0.2911
# Epoch 694/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 695/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2912
# Epoch 696/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2911
# Epoch 697/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2911
# Epoch 698/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 699/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 700/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 701/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 702/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 703/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 704/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2910
# Epoch 705/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 706/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2912
# Epoch 707/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 708/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 709/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 710/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 711/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 712/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 713/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 714/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 715/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 716/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 717/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 718/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 719/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 720/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 721/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2911
# Epoch 722/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 723/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2910
# Epoch 724/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 725/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 726/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 727/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 728/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2912
# Epoch 729/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 730/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 731/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 732/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 733/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9147 - loss: 0.2909
# Epoch 734/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9145 - loss: 0.2911
# Epoch 735/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 736/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 737/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2909
# Epoch 738/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 739/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 740/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 741/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 742/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 743/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 744/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 745/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.2911
# Epoch 746/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2910
# Epoch 747/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 748/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 749/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2909
# Epoch 750/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 751/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 752/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2909
# Epoch 753/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9139 - loss: 0.2910
# Epoch 754/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 755/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 756/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 757/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 758/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 759/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 760/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 761/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 762/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 763/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 764/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 765/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2909
# Epoch 766/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2911
# Epoch 767/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 768/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 769/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2910
# Epoch 770/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2912
# Epoch 771/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 772/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 773/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 774/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 775/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 776/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.2910
# Epoch 777/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 778/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 779/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 780/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2911
# Epoch 781/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2910
# Epoch 782/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 783/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2909
# Epoch 784/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2911
# Epoch 785/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.2910
# Epoch 786/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2910
# Epoch 787/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2910
# Epoch 788/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 789/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2911
# Epoch 790/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9145 - loss: 0.2910
# Epoch 791/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 792/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 793/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 794/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9147 - loss: 0.2910
# Epoch 795/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 796/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2910
# Epoch 797/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2910
# Epoch 798/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.2910
# Epoch 799/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2911
# Epoch 800/800
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2910
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Test accuracy: 0.9114
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot of a digit and its PSI

# %%
out_dir_histogram = './out_data/Figs_histogram/'
if not os.path.exists(out_dir_histogram):
    os.makedirs(out_dir_histogram)

idx_to_plot = 30000

fig, (a0, a1) = plt.subplots(nrows=1, ncols=2, width_ratios=[1, 3], figsize=(12,8))
a0.imshow(digit_train[idx_to_plot], aspect= 0.1, cmap='gray')
a0.set_title(f'Digit {digit_train_class[idx_to_plot]} chopped and merged')
a1.barh(range(1,len(digit_train_reduced_np[idx_to_plot,1:])+1), digit_train_reduced_np[idx_to_plot,1:], color='red', alpha=1)
a1.set_xlim([np.min(digit_train_reduced_np[:,1:]), np.max(digit_train_reduced_np[:,1:])])
a1.set_ylim([0, 196])
a1.invert_yaxis()
a1.set_title(f'PSI of Digit {digit_train_class[idx_to_plot]}')
plt.show()
plt.savefig(out_dir_histogram+f'histogram_digit_{digit_train_class[idx_to_plot]}_idx_{idx_to_plot}.png', format="png", dpi=1200)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
